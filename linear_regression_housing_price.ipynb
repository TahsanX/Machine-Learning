# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df['area'], df['price'])
plt.xlabel("Area")
plt.ylabel("Price")
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df['price'])
# Out:
# LinearRegression()

# %%
print(reg.coef_)      # slope
print(reg.intercept_) # intercept
# Out:
# [135.78767123]
# 180616.43835616432

# %%
reg.predict([[3300]])
m = reg.coef_
c = reg.intercept_
x = df['area']
y = m*x+c
plt.scatter(df['area'], df['price'])
plt.plot(x,y)
# Out:
# d:\Destinations\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
